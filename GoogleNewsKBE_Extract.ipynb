# %%
"""
Google News KBE Prediction Scraper - Simplified
Captures 25-50 highest-quality articles per day for predicting next-day VIX changes.
"""
import os
import hashlib
import re
import time
import random
from datetime import datetime, timedelta
from urllib.parse import urlparse, parse_qsl, urlencode, urlunparse
import pandas as pd
from pygooglenews import GoogleNews

# ============================================================================
# CONFIGURATION SECTION
# ============================================================================

# VERSION C: HYBRID (Recommended for testing)
TIER1_REGIONAL_STRESS = [
    # Specific bank names (high signal)
    '("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") AND (failure OR crisis OR collapse)',
    '("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stress OR concerns OR deposit OR loss)',
    '"New York Community Bancorp" AND (warning OR loss OR concern OR writedown)',
    
    # Regional banks generally
    '"regional bank" AND "United States" AND (failure OR crisis OR stress)',
    '"regional bank" AND (deposit OR outflow OR run)',
    
    # FDIC/emergency
    '"FDIC" AND (takeover OR receivership OR intervention)',
    '"Fed emergency" AND (facility OR liquidity)',
    '"discount window" AND surge',
]

TIER2_MAJOR_PROBLEMS = [
    # Major banks ONLY for problems
    '("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup") AND (warning OR loss OR downgrade)',
    
    # Fed surprises
    '"Federal Reserve" AND emergency AND (meeting OR action)',
    '"FOMC" AND (surprise OR unexpected)',
    '"Jerome Powell" AND (emergency OR urgent)',
    
    # Credit market stress
    '"commercial real estate" AND (default OR distress OR crisis) AND bank',
    '"CRE loans" AND (losses OR writedown)',
    '"credit rating" AND downgrade AND bank',
]

TIER3_SECTOR_SIGNALS = [
    # Sector-wide
    '"bank earnings" AND "United States" AND (warning OR miss)',
    '"net interest margin" AND (compress OR decline)',
    '"bank reserves" AND (decline OR drain)',
    '"loan losses" AND (rising OR surge)',
    '"stress test" AND (fail OR concern)',
    '"Treasury yields" AND spike AND banks',
]


# Combine queries with priority weights
ALL_QUERIES = (
    [(q, 10) for q in TIER1_REGIONAL_STRESS] +      # 10 queries, weight 10
    [(q, 8) for q in TIER2_MAJOR_PROBLEMS] +   # 12 queries, weight 8
    [(q, 6) for q in TIER3_SECTOR_SIGNALS]         # 10 queries, weight 6
)

# API configuration
LANG = "en"
COUNTRY = "US"
MAX_ARTICLES_PER_DAY = 40  # Target 40 articles (range will be 25-50)
MAX_ARTICLES_PER_QUERY = 10  # Don't pull more than 10 from any single query

# Output directory
OUTPUT_DIR = 'data/vix_training'

# Rate limiting
MIN_DELAY = 1.0  # Minimum seconds between queries
MAX_DELAY = 2.0  # Maximum seconds between queries
ERROR_DELAY = 5  # Seconds to wait after error
DAY_DELAY_MIN = 2  # Minimum seconds between days
DAY_DELAY_MAX = 4  # Maximum seconds between days

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def clean_url(url: str) -> str:
    """Remove common tracking params to get canonical URL."""
    try:
        p = urlparse(url)
        if not p.scheme:
            return url
        q = [(k, v) for k, v in parse_qsl(p.query, keep_blank_values=True)
             if not re.match(r'^(utm_|gclid|fbclid|mc_|ref)', k, re.I)]
        return urlunparse((p.scheme, p.netloc, p.path, "", urlencode(q), ""))
    except Exception:
        return url


def make_id(title: str, canonical_link: str) -> str:
    """Generate unique ID for article based on title and link."""
    base = f"{(title or '').strip()}|{(canonical_link or '').strip()}"
    return hashlib.sha256(base.encode("utf-8")).hexdigest()


def write_daily_file(rows: list, date_str: str) -> None:
    """Write articles for a specific day to CSV."""
    if not rows:
        return
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    output_path = os.path.join(OUTPUT_DIR, f'{date_str}.csv')
    
    df = pd.DataFrame(rows)
    df.to_csv(output_path, index=False)
    print(f"  ✓ Saved {len(rows)} articles to {output_path}")


# ============================================================================
# MAIN SCRAPING FUNCTION
# ============================================================================

def run_pull_for_date(target_date: datetime, max_articles: int = 40) -> pd.DataFrame:
    """
    Pull news for a specific date with priority-based query system.
    
    Args:
        target_date: The date to pull news for (articles from this day predict VIX on next day)
        max_articles: Maximum number of articles to collect
    
    Returns:
        DataFrame of collected articles
    """
    gn = GoogleNews(lang=LANG, country=COUNTRY)
    run_iso = datetime.now().isoformat()
    
    from_date = target_date.strftime('%Y-%m-%d')
    to_date = (target_date + timedelta(days=1)).strftime('%Y-%m-%d')
    prediction_date = to_date
    
    print(f"\n{'='*70}")
    print(f"Fetching articles for {from_date}")
    print(f"(To predict VIX change on {prediction_date})")
    print(f"Target: {max_articles} articles | Max queries: {len(ALL_QUERIES)}")
    print(f"{'='*70}")
    
    collected_articles = []
    seen_ids = set()  # Track duplicates within this day only
    queries_executed = 0
    
    # Process queries in priority order
    for query_idx, (query, priority_weight) in enumerate(ALL_QUERIES, 1):
        # Stop if we've collected enough articles
        if len(collected_articles) >= max_articles:
            print(f"\n✓ Reached target of {max_articles} articles. Stopping.")
            break
        
        print(f"[{query_idx}/{len(ALL_QUERIES)}] P={priority_weight} | {query[:65]}...")
        
        try:
            # Fetch articles for this query
            res = gn.search(query, from_=from_date, to_=to_date)
            entries = res.get("entries", [])
            queries_executed += 1
            
            articles_added = 0
            
            for e in entries[:MAX_ARTICLES_PER_QUERY]:
                # Stop if we've hit the daily limit
                if len(collected_articles) >= max_articles:
                    break
                
                title = e.get("title", "")
                link = e.get("link", "")
                src = (e.get("source", {}) or {}).get("title", "")
                published = e.get("published", "")
                
                canonical = clean_url(link)
                _id = make_id(title, canonical)
                
                # Skip duplicates within this day
                if _id in seen_ids:
                    continue
                
                # Create article record
                row = {
                    "id": _id,
                    "title": title,
                    "link": canonical,
                    "published": published,
                    "source": src,
                    "query": query,
                    "priority_weight": priority_weight,
                    "article_date": from_date,
                    "prediction_date": prediction_date,
                    "fetched_at": run_iso
                }
                
                collected_articles.append(row)
                seen_ids.add(_id)
                articles_added += 1
            
            print(f"  → +{articles_added} | Total: {len(collected_articles)}/{max_articles}")
            
            # Rate limiting
            delay = random.uniform(MIN_DELAY, MAX_DELAY)
            time.sleep(delay)
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
            time.sleep(ERROR_DELAY)
            continue
    
    # Summary
    print(f"\n{'─'*70}")
    print(f"SUMMARY: {len(collected_articles)} articles from {queries_executed} queries")
    print(f"{'─'*70}")
    
    # Save results
    if collected_articles:
        write_daily_file(collected_articles, from_date)
    
    return pd.DataFrame(collected_articles)


def run_date_range(start_date: datetime, end_date: datetime, max_articles_per_day: int = 40):
    """
    Collect articles for a range of dates.
    
    Args:
        start_date: First date to collect
        end_date: Last date to collect
        max_articles_per_day: Target articles per day
    """
    current_date = start_date
    total_articles = 0
    total_queries = 0
    days_processed = 0
    start_time = time.time()
    
    total_days = (end_date - start_date).days + 1
    
    print("\n" + "="*70)
    print("KBE PREDICTION DATASET COLLECTION")
    print("="*70)
    print(f"Date range: {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}")
    print(f"Total days: {total_days}")
    print(f"Target: {max_articles_per_day} articles per day")
    print(f"Query pool: {len(ALL_QUERIES)} queries (Tier 1-3)")
    print("="*70 + "\n")
    
    while current_date <= end_date:
        try:
            # Collect articles for this date
            df = run_pull_for_date(current_date, max_articles=max_articles_per_day)
            
            # Track stats
            total_articles += len(df)
            queries_used = df['query'].nunique() if len(df) > 0 else 0
            total_queries += queries_used
            days_processed += 1
            
            # Progress update every 10 days
            if days_processed % 10 == 0:
                elapsed_hours = (time.time() - start_time) / 3600
                days_remaining = (end_date - current_date).days
                queries_per_hour = total_queries / elapsed_hours if elapsed_hours > 0 else 0
                
                print(f"\n{'═'*70}")
                print(f"📊 PROGRESS UPDATE")
                print(f"{'═'*70}")
                print(f"Days: {days_processed}/{total_days} | Remaining: {days_remaining}")
                print(f"Articles: {total_articles} total ({total_articles/days_processed:.1f} avg/day)")
                print(f"Queries: {total_queries} total ({total_queries/days_processed:.1f} avg/day)")
                print(f"Rate: {queries_per_hour:.1f} queries/hour")
                print(f"Elapsed: {elapsed_hours:.2f}h | Est. remaining: {elapsed_hours/days_processed*days_remaining:.2f}h")
                print(f"{'═'*70}\n")
            
            # Short pause between days
            time.sleep(random.uniform(DAY_DELAY_MIN, DAY_DELAY_MAX))
            
        except KeyboardInterrupt:
            print("\n\n⚠️  Interrupted by user.")
            print(f"Completed: {days_processed}/{total_days} days")
            print(f"To resume, set START_DATE = datetime({current_date.year}, {current_date.month}, {current_date.day})")
            break
        except Exception as e:
            print(f"\n✗ Error processing {current_date.strftime('%Y-%m-%d')}: {e}")
            print(f"Continuing to next date...")
        
        current_date += timedelta(days=1)
    
    # Final summary
    total_time = time.time() - start_time
    print("\n" + "="*70)
    print("🎉 COLLECTION COMPLETE")
    print("="*70)
    print(f"Days processed: {days_processed}")
    print(f"Total articles: {total_articles}")
    print(f"Total queries: {total_queries}")
    print(f"Average: {total_articles/days_processed:.1f} articles/day, {total_queries/days_processed:.1f} queries/day")
    print(f"Runtime: {total_time/3600:.2f} hours")
    print(f"Query rate: {total_queries/(total_time/3600):.1f} queries/hour")
    print(f"\n📁 Output: {days_processed} CSV files in {OUTPUT_DIR}/")
    print("="*70 + "\n")


# ============================================================================
# MAIN EXECUTION
# ============================================================================

# if __name__ == "__main__":
#     # Set your date range here
#     START_DATE = datetime(2025, 1, 1)
#     END_DATE = datetime(2025, 1, 31)
#     ARTICLES_PER_DAY = 40
    
#     print("\n🚀 Starting VIX dataset collection...")
#     print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
#     print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
#     print(f"⚡ Fast mode: 1-2 second delays\n")
    
#     # Run collection
#     run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

# %%
"""
Google News DXY/USD Prediction Scraper
Captures high-quality articles from reputable sources for predicting USD index changes.
"""
import os
import hashlib
import re
import time
import random
from datetime import datetime, timedelta
from urllib.parse import urlparse, parse_qsl, urlencode, urlunparse
import pandas as pd
from pygooglenews import GoogleNews

# ============================================================================
# CONFIGURATION SECTION
# ============================================================================

# Reputable sources WITHOUT paywalls (reusable prefix)
# SOURCES = '(source:reuters OR source:cnbc OR source:marketwatch OR source:bloomberg OR source:apnews OR source:forbes OR source:axios OR source:politico OR source:bbc OR source:cnn OR source:investing.com OR source:thehill)'
SOURCES = '(source:cnbc)'
# TIER 1: Direct USD/DXY drivers (highest signal)
TIER1_USD_CATALYSTS = [
    # Fed policy shocks
    f'{SOURCES} "Federal Reserve" AND (emergency OR surprise OR pivot)',
    f'{SOURCES} "Jerome Powell" AND (dovish OR hawkish OR independence)',
    f'{SOURCES} "FOMC" AND (surprise OR unexpected OR emergency)',
    f'{SOURCES} "Fed rate" AND (cut OR hike OR hold) AND surprise',
    f'{SOURCES} "interest rate" AND "Federal Reserve" AND unexpected',
    
    # Inflation shocks
    f'{SOURCES} "CPI" AND "United States" AND (surprise OR miss OR beat)',
    f'{SOURCES} "core inflation" AND (higher OR lower) AND unexpected',
    f'{SOURCES} "PCE inflation" AND surprise',
    f'{SOURCES} "inflation data" AND (shock OR surprise OR unexpected)',
    
    # Jobs data shocks
    f'{SOURCES} "nonfarm payrolls" AND (miss OR beat OR surprise)',
    f'{SOURCES} "unemployment rate" AND (spike OR jump OR unexpected)',
    f'{SOURCES} "jobless claims" AND surge',
    f'{SOURCES} "jobs report" AND (disappointing OR strong OR weak)',
]

TIER2_TARIFF_TRADE_SHOCKS = [
    # Trump tariff events
    f'{SOURCES} "Trump" AND "tariff" AND (announce OR pause)',
    f'{SOURCES} "reciprocal tariff" AND (China OR global OR pause)',
    f'{SOURCES} "trade war" AND "United States" AND escalate',
    f'{SOURCES} "tariff" AND (retaliation OR countermeasures)',
    
    # Dollar policy statements
    f'{SOURCES} "dollar" AND (weaken OR strengthen) AND (Trump OR administration)',
    f'{SOURCES} "dollar index" AND (plunge OR surge OR crash OR rally)',
    f'{SOURCES} "DXY" AND (drop OR rally OR fall OR rise)',
    f'{SOURCES} "currency manipulation" AND dollar',
    
    # International responses
    f'{SOURCES} "tariff" AND (China OR Europe OR Canada OR Mexico) AND retaliate',
    f'{SOURCES} "trade tensions" AND dollar',
]

TIER3_MACRO_DRIVERS = [
    # Treasury market stress
    f'{SOURCES} "Treasury yield" AND (spike OR plunge OR surge)',
    f'{SOURCES} "bond market" AND (selloff OR rally OR volatility)',
    f'{SOURCES} "10-year yield" AND (jump OR fall OR soar)',
    f'{SOURCES} "bond vigilante"',
    
    # Growth/recession fears
    f'{SOURCES} "recession" AND "United States" AND (warning OR risk OR probability)',
    f'{SOURCES} "GDP growth" AND "United States" AND (downgrade OR upgrade OR forecast)',
    f'{SOURCES} "economic outlook" AND "United States" AND (deteriorate OR improve)',
    
    # Fed independence concerns
    f'{SOURCES} "Fed independence" AND (threat OR concern OR Trump)',
    f'{SOURCES} "Powell" AND (fired OR dismissed OR pressure OR attacks)',
    f'{SOURCES} "Federal Reserve" AND "political pressure"',
    
    # Dollar reserve status
    f'{SOURCES} "dollar" AND "reserve currency" AND (threat OR decline OR shift)',
    f'{SOURCES} "de-dollarization"',
    f'{SOURCES} "dollar dominance" AND (waning OR declining)',
    
    # Safe haven flows
    f'{SOURCES} "safe haven" AND (gold OR yen OR dollar)',
    f'{SOURCES} "risk off" AND dollar',
    f'{SOURCES} "flight to safety" AND currency',
    
    # Rate differentials
    f'{SOURCES} "rate differential" AND dollar',
    f'{SOURCES} "yield advantage" AND dollar',
]

# Combine queries with priority weights
ALL_QUERIES = (
    [(q, 10) for q in TIER1_USD_CATALYSTS] +      # 13 queries, weight 10
    [(q, 8) for q in TIER2_TARIFF_TRADE_SHOCKS] + # 10 queries, weight 8
    [(q, 6) for q in TIER3_MACRO_DRIVERS]         # 18 queries, weight 6
)

# API configuration
LANG = "en"
COUNTRY = "US"
MAX_ARTICLES_PER_DAY = 40  # Target 40 articles (range will be 25-50)
MAX_ARTICLES_PER_QUERY = 10  # Don't pull more than 10 from any single query

# Output directory
OUTPUT_DIR = 'data/dxy_training/cnbc/'

# Rate limiting
MIN_DELAY = 1.0  # Minimum seconds between queries
MAX_DELAY = 2.0  # Maximum seconds between queries
ERROR_DELAY = 5  # Seconds to wait after error
DAY_DELAY_MIN = 5  # Minimum seconds between days
DAY_DELAY_MAX = 10  # Maximum seconds between days

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def clean_url(url: str) -> str:
    """Remove common tracking params to get canonical URL."""
    try:
        p = urlparse(url)
        if not p.scheme:
            return url
        q = [(k, v) for k, v in parse_qsl(p.query, keep_blank_values=True)
             if not re.match(r'^(utm_|gclid|fbclid|mc_|ref)', k, re.I)]
        return urlunparse((p.scheme, p.netloc, p.path, "", urlencode(q), ""))
    except Exception:
        return url


def make_id(title: str, canonical_link: str) -> str:
    """Generate unique ID for article based on title and link."""
    base = f"{(title or '').strip()}|{(canonical_link or '').strip()}"
    return hashlib.sha256(base.encode("utf-8")).hexdigest()


def write_daily_file(rows: list, date_str: str) -> None:
    """Write articles for a specific day to CSV."""
    if not rows:
        return
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    output_path = os.path.join(OUTPUT_DIR, f'{date_str}.csv')
    
    df = pd.DataFrame(rows)
    df.to_csv(output_path, index=False)
    print(f"  ✓ Saved {len(rows)} articles to {output_path}")


# ============================================================================
# MAIN SCRAPING FUNCTION
# ============================================================================

def run_pull_for_date(target_date: datetime, max_articles: int = 40) -> pd.DataFrame:
    """
    Pull news for a specific date with priority-based query system.
    
    Args:
        target_date: The date to pull news for (articles from this day predict DXY on next day)
        max_articles: Maximum number of articles to collect
    
    Returns:
        DataFrame of collected articles
    """
    gn = GoogleNews(lang=LANG, country=COUNTRY)
    run_iso = datetime.now().isoformat()
    
    from_date = target_date.strftime('%Y-%m-%d')
    to_date = (target_date + timedelta(days=1)).strftime('%Y-%m-%d')
    prediction_date = to_date
    
    print(f"\n{'='*70}")
    print(f"Fetching articles for {from_date}")
    print(f"(To predict DXY change on {prediction_date})")
    print(f"Target: {max_articles} articles | Max queries: {len(ALL_QUERIES)}")
    print(f"{'='*70}")
    
    collected_articles = []
    seen_ids = set()  # Track duplicates within this day only
    queries_executed = 0
    
    # Process queries in priority order
    for query_idx, (query, priority_weight) in enumerate(ALL_QUERIES, 1):
        # Stop if we've collected enough articles
        if len(collected_articles) >= max_articles:
            print(f"\n✓ Reached target of {max_articles} articles. Stopping.")
            break
        
        # Show abbreviated query (remove source prefix for readability)
        query_display = query.replace(SOURCES, '[SOURCES]')
        print(f"[{query_idx}/{len(ALL_QUERIES)}] P={priority_weight} | {query_display[:65]}...")
        
        try:
            # Fetch articles for this query
            res = gn.search(query, from_=from_date, to_=to_date)
            entries = res.get("entries", [])
            queries_executed += 1
            
            articles_added = 0
            
            for e in entries[:MAX_ARTICLES_PER_QUERY]:
                # Stop if we've hit the daily limit
                if len(collected_articles) >= max_articles:
                    break
                
                title = e.get("title", "")
                link = e.get("link", "")
                src = (e.get("source", {}) or {}).get("title", "")
                published = e.get("published", "")
                
                canonical = clean_url(link)
                _id = make_id(title, canonical)
                
                # Skip duplicates within this day
                if _id in seen_ids:
                    continue
                
                # Create article record
                row = {
                    "id": _id,
                    "title": title,
                    "link": canonical,
                    "published": published,
                    "source": src,
                    "query": query_display,  # Store abbreviated version
                    "priority_weight": priority_weight,
                    "article_date": from_date,
                    "prediction_date": prediction_date,
                    "fetched_at": run_iso
                }
                
                collected_articles.append(row)
                seen_ids.add(_id)
                articles_added += 1
            
            print(f"  → +{articles_added} | Total: {len(collected_articles)}/{max_articles}")
            
            # Rate limiting
            delay = random.uniform(MIN_DELAY, MAX_DELAY)
            time.sleep(delay)
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
            time.sleep(ERROR_DELAY)
            continue
    
    # Summary
    print(f"\n{'─'*70}")
    print(f"SUMMARY: {len(collected_articles)} articles from {queries_executed} queries")
    if collected_articles:
        source_counts = pd.DataFrame(collected_articles)['source'].value_counts()
        print(f"Top sources: {dict(source_counts.head(5))}")
    print(f"{'─'*70}")
    
    # Save results
    if collected_articles:
        write_daily_file(collected_articles, from_date)
    
    return pd.DataFrame(collected_articles)


def run_date_range(start_date: datetime, end_date: datetime, max_articles_per_day: int = 40):
    """
    Collect articles for a range of dates.
    
    Args:
        start_date: First date to collect
        end_date: Last date to collect
        max_articles_per_day: Target articles per day
    """
    current_date = start_date
    total_articles = 0
    total_queries = 0
    days_processed = 0
    start_time = time.time()
    
    total_days = (end_date - start_date).days + 1
    
    print("\n" + "="*70)
    print("DXY/USD INDEX PREDICTION DATASET COLLECTION")
    print("="*70)
    print(f"Date range: {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}")
    print(f"Total days: {total_days}")
    print(f"Target: {max_articles_per_day} articles per day")
    print(f"Query pool: {len(ALL_QUERIES)} queries (Tier 1-3)")
    # print(f"Sources: Reuters, CNBC, MarketWatch, Bloomberg, AP, Forbes, Axios, Politico, etc.")
    print("Sources: CNBC")
    print("="*70 + "\n")
    
    while current_date <= end_date:
        try:
            # Collect articles for this date
            df = run_pull_for_date(current_date, max_articles=max_articles_per_day)
            
            # Track stats
            total_articles += len(df)
            queries_used = df['query'].nunique() if len(df) > 0 else 0
            total_queries += queries_used
            days_processed += 1
            
            # Progress update every 10 days
            if days_processed % 10 == 0:
                elapsed_hours = (time.time() - start_time) / 3600
                days_remaining = (end_date - current_date).days
                queries_per_hour = total_queries / elapsed_hours if elapsed_hours > 0 else 0
                
                print(f"\n{'═'*70}")
                print(f"📊 PROGRESS UPDATE")
                print(f"{'═'*70}")
                print(f"Days: {days_processed}/{total_days} | Remaining: {days_remaining}")
                print(f"Articles: {total_articles} total ({total_articles/days_processed:.1f} avg/day)")
                print(f"Queries: {total_queries} total ({total_queries/days_processed:.1f} avg/day)")
                print(f"Rate: {queries_per_hour:.1f} queries/hour")
                print(f"Elapsed: {elapsed_hours:.2f}h | Est. remaining: {elapsed_hours/days_processed*days_remaining:.2f}h")
                print(f"{'═'*70}\n")
            
            # Short pause between days
            time.sleep(random.uniform(DAY_DELAY_MIN, DAY_DELAY_MAX))
            
        except KeyboardInterrupt:
            print("\n\n⚠️  Interrupted by user.")
            print(f"Completed: {days_processed}/{total_days} days")
            print(f"To resume, set START_DATE = datetime({current_date.year}, {current_date.month}, {current_date.day})")
            break
        except Exception as e:
            print(f"\n✗ Error processing {current_date.strftime('%Y-%m-%d')}: {e}")
            print(f"Continuing to next date...")
        
        current_date += timedelta(days=1)
    
    # Final summary
    total_time = time.time() - start_time
    print("\n" + "="*70)
    print("🎉 COLLECTION COMPLETE")
    print("="*70)
    print(f"Days processed: {days_processed}")
    print(f"Total articles: {total_articles}")
    print(f"Total queries: {total_queries}")
    print(f"Average: {total_articles/days_processed:.1f} articles/day, {total_queries/days_processed:.1f} queries/day")
    print(f"Runtime: {total_time/3600:.2f} hours")
    print(f"Query rate: {total_queries/(total_time/3600):.1f} queries/hour")
    print(f"\n📁 Output: {days_processed} CSV files in {OUTPUT_DIR}/")
    print("="*70 + "\n")


# ============================================================================
# MAIN EXECUTION
# ============================================================================

# if __name__ == "__main__":
#     # Set your date range here
#     # Example: Capture the 2023-2025 period with major DXY events
#     START_DATE = datetime(2023, 1, 1)
#     END_DATE = datetime(2025, 12, 31)
#     ARTICLES_PER_DAY = 40
    
#     print("\n🚀 Starting DXY/USD dataset collection...")
#     print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
#     print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
#     print(f"📰 Sources: Reputable outlets (no paywalls)")
#     print(f"⚡ Rate limit: 1-2 second delays\n")
    
#     # Run collection
#     run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

# %%
START_DATE = datetime(2025, 1, 8)
END_DATE = datetime(2025, 1, 19)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# ======================================================================
# DXY/USD INDEX PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-01-08 to 2025-01-19
# Total days: 12
# Target: 40 articles per day
# Query pool: 41 queries (Tier 1-3)
# Sources: CNBC
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-01-08
# (To predict DXY change on 2025-01-09)
# Target: 40 articles | Max queries: 41
# ======================================================================
# [1/41] P=10 | [SOURCES] "Federal Reserve" AND (emergency OR surprise OR pivot)...
#   → +0 | Total: 0/40
# [2/41] P=10 | [SOURCES] "Jerome Powell" AND (dovish OR hawkish OR independence)...
#   → +0 | Total: 0/40
# [3/41] P=10 | [SOURCES] "FOMC" AND (surprise OR unexpected OR emergency)...
#   → +0 | Total: 0/40
# [4/41] P=10 | [SOURCES] "Fed rate" AND (cut OR hike OR hold) AND surprise...
#   → +0 | Total: 0/40
# [5/41] P=10 | [SOURCES] "interest rate" AND "Federal Reserve" AND unexpected...
#   → +0 | Total: 0/40
# [6/41] P=10 | [SOURCES] "CPI" AND "United States" AND (surprise OR miss OR beat...
#   → +0 | Total: 0/40
# [7/41] P=10 | [SOURCES] "core inflation" AND (higher OR lower) AND unexpected...
#   → +0 | Total: 0/40
# [8/41] P=10 | [SOURCES] "PCE inflation" AND surprise...
#   → +0 | Total: 0/40
# [9/41] P=10 | [SOURCES] "inflation data" AND (shock OR surprise OR unexpected)...
#   → +0 | Total: 0/40
# [10/41] P=10 | [SOURCES] "nonfarm payrolls" AND (miss OR beat OR surprise)...
#   → +0 | Total: 0/40
# [11/41] P=10 | [SOURCES] "unemployment rate" AND (spike OR jump OR unexpected)...
#   → +0 | Total: 0/40
# [12/41] P=10 | [SOURCES] "jobless claims" AND surge...
#   → +0 | Total: 0/40
# [13/41] P=10 | [SOURCES] "jobs report" AND (disappointing OR strong OR weak)...
#   → +0 | Total: 0/40
# [14/41] P=8 | [SOURCES] "Trump" AND "tariff" AND (announce OR pause)...
#   → +0 | Total: 0/40
# [15/41] P=8 | [SOURCES] "reciprocal tariff" AND (China OR global OR pause)...
#   → +0 | Total: 0/40
# [16/41] P=8 | [SOURCES] "trade war" AND "United States" AND escalate...
#   → +0 | Total: 0/40
# [17/41] P=8 | [SOURCES] "tariff" AND (retaliation OR countermeasures)...
#   → +0 | Total: 0/40
# [18/41] P=8 | [SOURCES] "dollar" AND (weaken OR strengthen) AND (Trump OR admin...
#   → +0 | Total: 0/40
# [19/41] P=8 | [SOURCES] "dollar index" AND (plunge OR surge OR crash OR rally)...
#   → +0 | Total: 0/40
# [20/41] P=8 | [SOURCES] "DXY" AND (drop OR rally OR fall OR rise)...
#   → +0 | Total: 0/40
# [21/41] P=8 | [SOURCES] "currency manipulation" AND dollar...
#   → +0 | Total: 0/40
# [22/41] P=8 | [SOURCES] "tariff" AND (China OR Europe OR Canada OR Mexico) AND ...
#   → +0 | Total: 0/40
# [23/41] P=8 | [SOURCES] "trade tensions" AND dollar...
#   → +0 | Total: 0/40
# [24/41] P=6 | [SOURCES] "Treasury yield" AND (spike OR plunge OR surge)...
#   → +0 | Total: 0/40
# [25/41] P=6 | [SOURCES] "bond market" AND (selloff OR rally OR volatility)...
#   → +0 | Total: 0/40
# [26/41] P=6 | [SOURCES] "10-year yield" AND (jump OR fall OR soar)...
#   → +0 | Total: 0/40
# [27/41] P=6 | [SOURCES] "bond vigilante"...
#   → +0 | Total: 0/40
# [28/41] P=6 | [SOURCES] "recession" AND "United States" AND (warning OR risk OR...
#   → +0 | Total: 0/40
# [29/41] P=6 | [SOURCES] "GDP growth" AND "United States" AND (downgrade OR upgr...
#   → +0 | Total: 0/40
# [30/41] P=6 | [SOURCES] "economic outlook" AND "United States" AND (deteriorate...
#   → +0 | Total: 0/40
# [31/41] P=6 | [SOURCES] "Fed independence" AND (threat OR concern OR Trump)...
#   → +0 | Total: 0/40
# [32/41] P=6 | [SOURCES] "Powell" AND (fired OR dismissed OR pressure OR attacks...
#
#
# ⚠️  Interrupted by user.
# Completed: 0/12 days
# To resume, set START_DATE = datetime(2025, 1, 8)
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 0
# Total articles: 0
# Total queries: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 END_DATE = datetime(2025, 1, 19)
#       3 ARTICLES_PER_DAY = 40
# ----> 4 run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
#
# Cell In[4], line 342, in run_date_range(start_date, end_date, max_articles_per_day)
#     340 print(f"Total articles: {total_articles}")
#     341 print(f"Total queries: {total_queries}")
# --> 342 print(f"Average: {total_articles/days_processed:.1f} articles/day, {total_queries/days_processed:.1f} queries/day")
#     343 print(f"Runtime: {total_time/3600:.2f} hours")
#     344 print(f"Query rate: {total_queries/(total_time/3600):.1f} queries/hour")
#
# ZeroDivisionError: division by zero

# %%
start_time = time.time()

START_DATE = datetime(2025, 4, 1)
END_DATE = datetime(2025, 4, 1)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# ======================================================================
# DXY/USD INDEX PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-04-01 to 2025-04-01
# Total days: 1
# Target: 40 articles per day
# Query pool: 41 queries (Tier 1-3)
# Sources: CNBC
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-04-01
# (To predict DXY change on 2025-04-02)
# Target: 40 articles | Max queries: 41
# ======================================================================
# [1/41] P=10 | [SOURCES] "Federal Reserve" AND (emergency OR surprise OR pivot)...
#   → +0 | Total: 0/40
# [2/41] P=10 | [SOURCES] "Jerome Powell" AND (dovish OR hawkish OR independence)...
#   → +0 | Total: 0/40
# [3/41] P=10 | [SOURCES] "FOMC" AND (surprise OR unexpected OR emergency)...
#   → +0 | Total: 0/40
# [4/41] P=10 | [SOURCES] "Fed rate" AND (cut OR hike OR hold) AND surprise...
#   → +0 | Total: 0/40
# [5/41] P=10 | [SOURCES] "interest rate" AND "Federal Reserve" AND unexpected...
#   → +0 | Total: 0/40
# [6/41] P=10 | [SOURCES] "CPI" AND "United States" AND (surprise OR miss OR beat...
#   → +0 | Total: 0/40
# [7/41] P=10 | [SOURCES] "core inflation" AND (higher OR lower) AND unexpected...
#   → +0 | Total: 0/40
# [8/41] P=10 | [SOURCES] "PCE inflation" AND surprise...
#   → +0 | Total: 0/40
# [9/41] P=10 | [SOURCES] "inflation data" AND (shock OR surprise OR unexpected)...
#   → +0 | Total: 0/40
# [10/41] P=10 | [SOURCES] "nonfarm payrolls" AND (miss OR beat OR surprise)...
#   → +0 | Total: 0/40
# [11/41] P=10 | [SOURCES] "unemployment rate" AND (spike OR jump OR unexpected)...
#   → +0 | Total: 0/40
# [12/41] P=10 | [SOURCES] "jobless claims" AND surge...
#   → +0 | Total: 0/40
# [13/41] P=10 | [SOURCES] "jobs report" AND (disappointing OR strong OR weak)...
#   → +0 | Total: 0/40
# [14/41] P=8 | [SOURCES] "Trump" AND "tariff" AND (announce OR pause)...
#   → +2 | Total: 2/40
# [15/41] P=8 | [SOURCES] "reciprocal tariff" AND (China OR global OR pause)...
#   → +0 | Total: 2/40
# [16/41] P=8 | [SOURCES] "trade war" AND "United States" AND escalate...
#   → +0 | Total: 2/40
# [17/41] P=8 | [SOURCES] "tariff" AND (retaliation OR countermeasures)...
#   → +0 | Total: 2/40
# [18/41] P=8 | [SOURCES] "dollar" AND (weaken OR strengthen) AND (Trump OR admin...
#   → +0 | Total: 2/40
# [19/41] P=8 | [SOURCES] "dollar index" AND (plunge OR surge OR crash OR rally)...
#   → +0 | Total: 2/40
# [20/41] P=8 | [SOURCES] "DXY" AND (drop OR rally OR fall OR rise)...
#   → +0 | Total: 2/40
# [21/41] P=8 | [SOURCES] "currency manipulation" AND dollar...
#   → +0 | Total: 2/40
# [22/41] P=8 | [SOURCES] "tariff" AND (China OR Europe OR Canada OR Mexico) AND ...
#   → +0 | Total: 2/40
# [23/41] P=8 | [SOURCES] "trade tensions" AND dollar...
#   → +0 | Total: 2/40
# [24/41] P=6 | [SOURCES] "Treasury yield" AND (spike OR plunge OR surge)...
#   → +0 | Total: 2/40
# [25/41] P=6 | [SOURCES] "bond market" AND (selloff OR rally OR volatility)...
#   → +0 | Total: 2/40
# [26/41] P=6 | [SOURCES] "10-year yield" AND (jump OR fall OR soar)...
#   → +0 | Total: 2/40
# [27/41] P=6 | [SOURCES] "bond vigilante"...
#   → +0 | Total: 2/40
# [28/41] P=6 | [SOURCES] "recession" AND "United States" AND (warning OR risk OR...
#   → +0 | Total: 2/40
# [29/41] P=6 | [SOURCES] "GDP growth" AND "United States" AND (downgrade OR upgr...
#   → +0 | Total: 2/40
# [30/41] P=6 | [SOURCES] "economic outlook" AND "United States" AND (deteriorate...
#   → +0 | Total: 2/40
# [31/41] P=6 | [SOURCES] "Fed independence" AND (threat OR concern OR Trump)...
#   → +0 | Total: 2/40
# [32/41] P=6 | [SOURCES] "Powell" AND (fired OR dismissed OR pressure OR attacks...
#   → +0 | Total: 2/40
# [33/41] P=6 | [SOURCES] "Federal Reserve" AND "political pressure"...
#   → +0 | Total: 2/40
# [34/41] P=6 | [SOURCES] "dollar" AND "reserve currency" AND (threat OR decline ...
#   → +0 | Total: 2/40
# [35/41] P=6 | [SOURCES] "de-dollarization"...
#   → +0 | Total: 2/40
# [36/41] P=6 | [SOURCES] "dollar dominance" AND (waning OR declining)...
#   → +0 | Total: 2/40
# [37/41] P=6 | [SOURCES] "safe haven" AND (gold OR yen OR dollar)...
#   → +0 | Total: 2/40
# [38/41] P=6 | [SOURCES] "risk off" AND dollar...
#   → +0 | Total: 2/40
# [39/41] P=6 | [SOURCES] "flight to safety" AND currency...
#   → +0 | Total: 2/40
# [40/41] P=6 | [SOURCES] "rate differential" AND dollar...
#   → +0 | Total: 2/40
# [41/41] P=6 | [SOURCES] "yield advantage" AND dollar...
#   → +0 | Total: 2/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 2 articles from 41 queries
# Top sources: {'CNBC': 1, 'FBC News': 1}
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 2 articles to data/dxy_training/cnbc/2025-04-01.csv
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 1
# Total articles: 2
# Total queries: 1
# Average: 2.0 articles/day, 1.0 queries/day
# Runtime: 0.03 hours
# Query rate: 34.9 queries/hour
#
# 📁 Output: 1 CSV files in data/dxy_training/cnbc//
# ======================================================================
#
# Elapsed time: 103.20 seconds

# %%
start_time = time.time()

START_DATE = datetime(2025, 5, 23)
END_DATE = datetime(2025, 5, 23)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time//60} minutes {elapsed_time:.2f} seconds")
# Out:
# ======================================================================
# DXY/USD INDEX PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-05-23 to 2025-05-23
# Total days: 1
# Target: 40 articles per day
# Query pool: 41 queries (Tier 1-3)
# Sources: CNBC
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-05-23
# (To predict DXY change on 2025-05-24)
# Target: 40 articles | Max queries: 41
# ======================================================================
# [1/41] P=10 | [SOURCES] "Federal Reserve" AND (emergency OR surprise OR pivot)...
#   → +0 | Total: 0/40
# [2/41] P=10 | [SOURCES] "Jerome Powell" AND (dovish OR hawkish OR independence)...
#   → +0 | Total: 0/40
# [3/41] P=10 | [SOURCES] "FOMC" AND (surprise OR unexpected OR emergency)...
#   → +0 | Total: 0/40
# [4/41] P=10 | [SOURCES] "Fed rate" AND (cut OR hike OR hold) AND surprise...
#   → +0 | Total: 0/40
# [5/41] P=10 | [SOURCES] "interest rate" AND "Federal Reserve" AND unexpected...
#   → +0 | Total: 0/40
# [6/41] P=10 | [SOURCES] "CPI" AND "United States" AND (surprise OR miss OR beat...
#   → +0 | Total: 0/40
# [7/41] P=10 | [SOURCES] "core inflation" AND (higher OR lower) AND unexpected...
#   → +0 | Total: 0/40
# [8/41] P=10 | [SOURCES] "PCE inflation" AND surprise...
#   → +0 | Total: 0/40
# [9/41] P=10 | [SOURCES] "inflation data" AND (shock OR surprise OR unexpected)...
#   → +0 | Total: 0/40
# [10/41] P=10 | [SOURCES] "nonfarm payrolls" AND (miss OR beat OR surprise)...
#   → +0 | Total: 0/40
# [11/41] P=10 | [SOURCES] "unemployment rate" AND (spike OR jump OR unexpected)...
#   → +0 | Total: 0/40
# [12/41] P=10 | [SOURCES] "jobless claims" AND surge...
#   → +0 | Total: 0/40
# [13/41] P=10 | [SOURCES] "jobs report" AND (disappointing OR strong OR weak)...
#   → +0 | Total: 0/40
# [14/41] P=8 | [SOURCES] "Trump" AND "tariff" AND (announce OR pause)...
#   → +0 | Total: 0/40
# [15/41] P=8 | [SOURCES] "reciprocal tariff" AND (China OR global OR pause)...
#   → +0 | Total: 0/40
# [16/41] P=8 | [SOURCES] "trade war" AND "United States" AND escalate...
#   → +0 | Total: 0/40
# [17/41] P=8 | [SOURCES] "tariff" AND (retaliation OR countermeasures)...
#   → +0 | Total: 0/40
# [18/41] P=8 | [SOURCES] "dollar" AND (weaken OR strengthen) AND (Trump OR admin...
#   → +0 | Total: 0/40
# [19/41] P=8 | [SOURCES] "dollar index" AND (plunge OR surge OR crash OR rally)...
#   → +0 | Total: 0/40
# [20/41] P=8 | [SOURCES] "DXY" AND (drop OR rally OR fall OR rise)...
#   → +0 | Total: 0/40
# [21/41] P=8 | [SOURCES] "currency manipulation" AND dollar...
#   → +0 | Total: 0/40
# [22/41] P=8 | [SOURCES] "tariff" AND (China OR Europe OR Canada OR Mexico) AND ...
#   → +0 | Total: 0/40
# [23/41] P=8 | [SOURCES] "trade tensions" AND dollar...
#   → +0 | Total: 0/40
# [24/41] P=6 | [SOURCES] "Treasury yield" AND (spike OR plunge OR surge)...
#   → +0 | Total: 0/40
# [25/41] P=6 | [SOURCES] "bond market" AND (selloff OR rally OR volatility)...
#   → +0 | Total: 0/40
# [26/41] P=6 | [SOURCES] "10-year yield" AND (jump OR fall OR soar)...
#   → +0 | Total: 0/40
# [27/41] P=6 | [SOURCES] "bond vigilante"...
#   → +0 | Total: 0/40
# [28/41] P=6 | [SOURCES] "recession" AND "United States" AND (warning OR risk OR...
#   → +0 | Total: 0/40
# [29/41] P=6 | [SOURCES] "GDP growth" AND "United States" AND (downgrade OR upgr...
#   → +0 | Total: 0/40
# [30/41] P=6 | [SOURCES] "economic outlook" AND "United States" AND (deteriorate...
#   → +0 | Total: 0/40
# [31/41] P=6 | [SOURCES] "Fed independence" AND (threat OR concern OR Trump)...
#   → +0 | Total: 0/40
# [32/41] P=6 | [SOURCES] "Powell" AND (fired OR dismissed OR pressure OR attacks...
#   → +0 | Total: 0/40
# [33/41] P=6 | [SOURCES] "Federal Reserve" AND "political pressure"...
#   → +0 | Total: 0/40
# [34/41] P=6 | [SOURCES] "dollar" AND "reserve currency" AND (threat OR decline ...
#   → +0 | Total: 0/40
# [35/41] P=6 | [SOURCES] "de-dollarization"...
#   → +0 | Total: 0/40
# [36/41] P=6 | [SOURCES] "dollar dominance" AND (waning OR declining)...
#   → +0 | Total: 0/40
# [37/41] P=6 | [SOURCES] "safe haven" AND (gold OR yen OR dollar)...
#   → +0 | Total: 0/40
# [38/41] P=6 | [SOURCES] "risk off" AND dollar...
#   → +0 | Total: 0/40
# [39/41] P=6 | [SOURCES] "flight to safety" AND currency...
#   → +0 | Total: 0/40
# [40/41] P=6 | [SOURCES] "rate differential" AND dollar...
#   → +0 | Total: 0/40
# [41/41] P=6 | [SOURCES] "yield advantage" AND dollar...
#   → +0 | Total: 0/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 0 articles from 41 queries
# ──────────────────────────────────────────────────────────────────────
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 1
# Total articles: 0
# Total queries: 0
# Average: 0.0 articles/day, 0.0 queries/day
# Runtime: 0.03 hours
# Query rate: 0.0 queries/hour
#
# 📁 Output: 1 CSV files in data/dxy_training/cnbc//
# ======================================================================
#
# Elapsed time: 1.0 minutes 104.44 seconds

# %%
start_time = time.time()

START_DATE = datetime(2025, 6, 1)
END_DATE = datetime(2025, 6, 30)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")

# %%
start_time = time.time()

START_DATE = datetime(2025, 7, 1)
END_DATE = datetime(2025, 7, 31)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")

# %%
start_time = time.time()

START_DATE = datetime(2025, 8, 1)
END_DATE = datetime(2025, 8, 31)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")

# %%
start_time = time.time()

START_DATE = datetime(2025, 9, 1)
END_DATE = datetime(2025, 9, 30)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")

# %%
start_time = time.time()

START_DATE = datetime(2025, 10, 1)
END_DATE = datetime(2025, 10, 31)
ARTICLES_PER_DAY = 40
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)

elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")

# %%
# Jan-Feb
START_DATE = datetime(2025, 1, 1)
END_DATE = datetime(2025, 2, 28)
ARTICLES_PER_DAY = 40

print("\n🚀 Starting KBE dataset collection...")
print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
print(f"⚡ Fast mode: 1-2 second delays\n")

# Run collection
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# 🚀 Starting KBE dataset collection...
# 📅 Date range: 2025-01-01 to 2025-02-28
# 🎯 Target: 40 articles per day
# ⚡ Fast mode: 1-2 second delays
#
#
# ======================================================================
# KBE PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-01-01 to 2025-02-28
# Total days: 59
# Target: 40 articles per day
# Query pool: 21 queries (Tier 1-3)
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-01-01
# (To predict VIX change on 2025-01-02)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 12/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 12/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 12/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 12/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 20/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 20/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 21/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 21/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 21/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 22/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 22/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 23/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 23/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 23 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 23 articles to data/vix_training/2025-01-01.csv
#
# ======================================================================
# Fetching articles for 2025-01-02
# (To predict VIX change on 2025-01-03)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 15/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 15/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 15/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 15/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 20/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 20/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 22/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 23/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 23/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 25/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 25/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 26/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 26/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 26 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 26 articles to data/vix_training/2025-01-02.csv
#
# ======================================================================
# Fetching articles for 2025-01-03
# (To predict VIX change on 2025-01-04)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +5 | Total: 7/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 7/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 7/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 7/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 11/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 11/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 12/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 13/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 13/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 14/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 14/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 14/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 14/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 14 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 14 articles to data/vix_training/2025-01-03.csv
#
# ======================================================================
# Fetching articles for 2025-01-04
# (To predict VIX change on 2025-01-05)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 0/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 0/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 1/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +2 | Total: 3/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 4/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 4/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 4/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 8/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 8/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 9/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 9/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 9/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 9/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 9/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 9/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 9/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 9 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 9 articles to data/vix_training/2025-01-04.csv
#
# ======================================================================
# Fetching articles for 2025-01-05
# (To predict VIX change on 2025-01-06)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +4 | Total: 8/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 9/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 9/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 9/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 15/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 16/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 17/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 17/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 17/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 17/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 17/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 17/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 17/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 17 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 17 articles to data/vix_training/2025-01-05.csv
#
# ======================================================================
# Fetching articles for 2025-01-06
# (To predict VIX change on 2025-01-07)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 14/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 14/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 14/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 23/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +3 | Total: 26/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 26/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 26/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 27/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 27/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +1 | Total: 28/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 29/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +2 | Total: 31/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 31 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 31 articles to data/vix_training/2025-01-06.csv
#
# ======================================================================
# Fetching articles for 2025-01-07
# (To predict VIX change on 2025-01-08)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 17/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 21/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 31/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 32/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 34/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 34/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 36/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 36/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 36/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 36/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +4 | Total: 40/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-07.csv
#
# ======================================================================
# Fetching articles for 2025-01-08
# (To predict VIX change on 2025-01-09)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 30/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-08.csv
#
# ======================================================================
# Fetching articles for 2025-01-09
# (To predict VIX change on 2025-01-10)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 10/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 23/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 33/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 33/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 37/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-09.csv
#
# ======================================================================
# Fetching articles for 2025-01-10
# (To predict VIX change on 2025-01-11)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 3/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 3/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 15/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 15/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 15/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 20/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 21/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 24/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 24/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 26/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 27/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 27/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 27/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +3 | Total: 30/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 30 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 30 articles to data/vix_training/2025-01-10.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 10/59 | Remaining: 49
# Articles: 270 total (27.0 avg/day)
# Queries: 86 total (8.6 avg/day)
# Rate: 639.6 queries/hour
# Elapsed: 0.13h | Est. remaining: 0.66h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-01-11
# (To predict VIX change on 2025-01-12)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 0/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 0/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 0/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 0/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 7/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 7/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 8/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 8/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 9/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 9/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 9/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 9/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 9/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 10/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 10/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 11/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 11/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 11 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 11 articles to data/vix_training/2025-01-11.csv
#
# ======================================================================
# Fetching articles for 2025-01-12
# (To predict VIX change on 2025-01-13)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 13/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 14/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 14/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 24/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 26/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 29/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 29/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 31/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 31/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 31/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 32/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +6 | Total: 38/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 38 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 38 articles to data/vix_training/2025-01-12.csv
#
# ======================================================================
# Fetching articles for 2025-01-13
# (To predict VIX change on 2025-01-14)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 10/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 10/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 20/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 20/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 20/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 29/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 31/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 34/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 34/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 37/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 37/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 37/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 38/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +2 | Total: 40/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-13.csv
#
# ======================================================================
# Fetching articles for 2025-01-14
# (To predict VIX change on 2025-01-15)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 10/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 26/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 26/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 33/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 33/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 35/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 35/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 36/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 36/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 36/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 37/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +3 | Total: 40/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-14.csv
#
# ======================================================================
# Fetching articles for 2025-01-15
# (To predict VIX change on 2025-01-16)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 11/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 18/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 18/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 18/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 28/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 28/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 28/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 37/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 39/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 16 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-15.csv
#
# ======================================================================
# Fetching articles for 2025-01-16
# (To predict VIX change on 2025-01-17)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 23/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 25/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 34/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 36/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 36/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +2 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-16.csv
#
# ======================================================================
# Fetching articles for 2025-01-17
# (To predict VIX change on 2025-01-18)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 10/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 20/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 20/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 20/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 30/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 30/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 31/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +8 | Total: 39/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 39/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 39/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 20 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-17.csv
#
# ======================================================================
# Fetching articles for 2025-01-18
# (To predict VIX change on 2025-01-19)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 3/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 3/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +6 | Total: 9/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 9/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 9/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 9/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 13/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 13/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 13/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 13/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 15/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 15/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 15/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 15/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 15/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 15 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 15 articles to data/vix_training/2025-01-18.csv
#
# ======================================================================
# Fetching articles for 2025-01-19
# (To predict VIX change on 2025-01-20)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 3/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 3/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +5 | Total: 8/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 15/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 15/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 15/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 18/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 18/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 19/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 19/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +9 | Total: 28/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 28/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 28/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 28/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +1 | Total: 29/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 29 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 29 articles to data/vix_training/2025-01-19.csv
#
# ======================================================================
# Fetching articles for 2025-01-20
# (To predict VIX change on 2025-01-21)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 31/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-20.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 20/59 | Remaining: 39
# Articles: 603 total (30.1 avg/day)
# Queries: 171 total (8.6 avg/day)
# Rate: 644.5 queries/hour
# Elapsed: 0.27h | Est. remaining: 0.52h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-01-21
# (To predict VIX change on 2025-01-22)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 30/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 30/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 33/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-01-21.csv
#
# ======================================================================
# Fetching articles for 2025-01-22
# (To predict VIX change on 2025-01-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
# ...
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +7 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 37/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-21.csv
#
# ======================================================================
# Fetching articles for 2025-02-22
# (To predict VIX change on 2025-02-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 14/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 14/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 14/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 17/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 17/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 20/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 20/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 22/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 24/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 24/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 24/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +1 | Total: 25/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 25 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 25 articles to data/vix_training/2025-02-22.csv
#
# ======================================================================
# Fetching articles for 2025-02-23
# (To predict VIX change on 2025-02-24)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 17/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 19/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 20/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 29/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +5 | Total: 34/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 34/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 36/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 37/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 37/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 20 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-23.csv
#
# ======================================================================
# Fetching articles for 2025-02-24
# (To predict VIX change on 2025-02-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 10/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 10/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 10/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 21/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 33/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +3 | Total: 36/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-24.csv
#
# ======================================================================
# Fetching articles for 2025-02-25
# (To predict VIX change on 2025-02-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 10/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 10/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 10/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 20/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 20/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 21/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 31/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +3 | Total: 34/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 38/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 39/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-25.csv
#
# ======================================================================
# Fetching articles for 2025-02-26
# (To predict VIX change on 2025-02-27)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 8/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 19/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 19/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 29/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +5 | Total: 34/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 35/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-26.csv
#
# ======================================================================
# Fetching articles for 2025-02-27
# (To predict VIX change on 2025-02-28)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 11/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 24/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 24/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 24/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 33/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 34/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 36/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 36/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-27.csv
#
# ======================================================================
# Fetching articles for 2025-02-28
# (To predict VIX change on 2025-03-01)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 12/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 23/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 31/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 31/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 32/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 32/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +5 | Total: 37/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 38/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 19 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-02-28.csv
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 59
# Total articles: 2002
# Total queries: 543
# Average: 33.9 articles/day, 9.2 queries/day
# Runtime: 0.74 hours
# Query rate: 732.4 queries/hour
#
# 📁 Output: 59 CSV files in data/vix_training/
# ======================================================================

# %%
# Jul - Aug
START_DATE = datetime(2025, 7, 1)
END_DATE = datetime(2025, 8, 31)
ARTICLES_PER_DAY = 40

print("\n🚀 Starting KBE dataset collection...")
print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
print(f"⚡ Fast mode: 1-2 second delays\n")

# Run collection
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# 🚀 Starting KBE dataset collection...
# 📅 Date range: 2025-07-01 to 2025-08-31
# 🎯 Target: 40 articles per day
# ⚡ Fast mode: 1-2 second delays
#
#
# ======================================================================
# KBE PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-07-01 to 2025-08-31
# Total days: 62
# Target: 40 articles per day
# Query pool: 21 queries (Tier 1-3)
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-07-01
# (To predict VIX change on 2025-07-02)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 10/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 27/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-01.csv
#
# ======================================================================
# Fetching articles for 2025-07-02
# (To predict VIX change on 2025-07-03)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 10/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 10/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 10/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 21/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 26/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 34/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 34/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-02.csv
#
# ======================================================================
# Fetching articles for 2025-07-03
# (To predict VIX change on 2025-07-04)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 10/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 10/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 22/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 22/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 27/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 34/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 34/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-03.csv
#
# ======================================================================
# Fetching articles for 2025-07-04
# (To predict VIX change on 2025-07-05)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +3 | Total: 5/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 5/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 5/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 6/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 10/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 10/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 14/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 14/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 16/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 17/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 17/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 17/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +1 | Total: 18/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 18 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 18 articles to data/vix_training/2025-07-04.csv
#
# ======================================================================
# Fetching articles for 2025-07-05
# (To predict VIX change on 2025-07-06)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +3 | Total: 7/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 7/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 7/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 8/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 9/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 9/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 12/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 12/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 12/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 12/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 12/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 12/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 12/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 12 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 12 articles to data/vix_training/2025-07-05.csv
#
# ======================================================================
# Fetching articles for 2025-07-06
# (To predict VIX change on 2025-07-07)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 18/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 19/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 20/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 24/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 25/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +9 | Total: 34/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +2 | Total: 36/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 36/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 38/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 38/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 39/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 39/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 39 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 39 articles to data/vix_training/2025-07-06.csv
#
# ======================================================================
# Fetching articles for 2025-07-07
# (To predict VIX change on 2025-07-08)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 28/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 30/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 39/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 14 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-07.csv
#
# ======================================================================
# Fetching articles for 2025-07-08
# (To predict VIX change on 2025-07-09)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 25/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 27/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 31/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 39/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 39/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-08.csv
#
# ======================================================================
# Fetching articles for 2025-07-09
# (To predict VIX change on 2025-07-10)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 26/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 35/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 35/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 38/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-09.csv
#
# ======================================================================
# Fetching articles for 2025-07-10
# (To predict VIX change on 2025-07-11)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 25/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 26/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 34/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-10.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 10/62 | Remaining: 52
# Articles: 349 total (34.9 avg/day)
# Queries: 86 total (8.6 avg/day)
# Rate: 725.3 queries/hour
# Elapsed: 0.12h | Est. remaining: 0.62h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-07-11
# (To predict VIX change on 2025-07-12)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 8/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 24/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 25/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 32/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 38/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 39/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-11.csv
#
# ======================================================================
# Fetching articles for 2025-07-12
# (To predict VIX change on 2025-07-13)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 1/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 1/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 1/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 10/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 11/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 11/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 17/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 21/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 21/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 21/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 21/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 22/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 23/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 23/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 23/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 23/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 23 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 23 articles to data/vix_training/2025-07-12.csv
#
# ======================================================================
# Fetching articles for 2025-07-13
# (To predict VIX change on 2025-07-14)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 8/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 15/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 17/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 25/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 35/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 35/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 39/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 16 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-13.csv
#
# ======================================================================
# Fetching articles for 2025-07-14
# (To predict VIX change on 2025-07-15)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 15/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 25/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 39/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-14.csv
#
# ======================================================================
# Fetching articles for 2025-07-15
# (To predict VIX change on 2025-07-16)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 10/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 10/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 10/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 10/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 20/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 26/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 26/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 14 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-15.csv
#
# ======================================================================
# Fetching articles for 2025-07-16
# (To predict VIX change on 2025-07-17)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 16/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 36/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-16.csv
#
# ======================================================================
# Fetching articles for 2025-07-17
# (To predict VIX change on 2025-07-18)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +8 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 21/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 21/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 21/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 21/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 31/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-17.csv
#
# ======================================================================
# Fetching articles for 2025-07-18
# (To predict VIX change on 2025-07-19)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 27/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 27/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-18.csv
#
# ======================================================================
# Fetching articles for 2025-07-19
# (To predict VIX change on 2025-07-20)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +6 | Total: 8/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 10/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 10/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 14/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 17/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 17/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 17/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 17/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +9 | Total: 26/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 26/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +2 | Total: 28/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +2 | Total: 30/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 30/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 30 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 30 articles to data/vix_training/2025-07-19.csv
#
# ======================================================================
# Fetching articles for 2025-07-20
# (To predict VIX change on 2025-07-21)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 28/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 35/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 35/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-20.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 20/62 | Remaining: 42
# Articles: 722 total (36.1 avg/day)
# Queries: 166 total (8.3 avg/day)
# Rate: 732.9 queries/hour
# Elapsed: 0.23h | Est. remaining: 0.48h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-07-21
# (To predict VIX change on 2025-07-22)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +3 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 25/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 33/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-21.csv
#
# ======================================================================
# Fetching articles for 2025-07-22
# (To predict VIX change on 2025-07-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 10/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 28/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-22.csv
#
# ======================================================================
# Fetching articles for 2025-07-23
# (To predict VIX change on 2025-07-24)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 15/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 25/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 33/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 33/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-23.csv
#
# ======================================================================
# Fetching articles for 2025-07-24
# (To predict VIX change on 2025-07-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 16/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 37/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-07-24.csv
#
# ======================================================================
# Fetching articles for 2025-07-25
# (To predict VIX change on 2025-07-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 16/40
# ...
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 22/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 30/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 32/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 32/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 35/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 35/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-24.csv
#
# ======================================================================
# Fetching articles for 2025-08-25
# (To predict VIX change on 2025-08-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 30/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-25.csv
#
# ======================================================================
# Fetching articles for 2025-08-26
# (To predict VIX change on 2025-08-27)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 15/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 25/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 26/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 31/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-26.csv
#
# ======================================================================
# Fetching articles for 2025-08-27
# (To predict VIX change on 2025-08-28)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 24/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 24/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 28/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 37/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 39/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-27.csv
#
# ======================================================================
# Fetching articles for 2025-08-28
# (To predict VIX change on 2025-08-29)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 17/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 27/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 28/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 34/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 39/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 14 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-28.csv
#
# ======================================================================
# Fetching articles for 2025-08-29
# (To predict VIX change on 2025-08-30)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 15/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 23/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 24/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 27/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 29/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +6 | Total: 35/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 36/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-29.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 60/62 | Remaining: 2
# Articles: 2247 total (37.5 avg/day)
# Queries: 522 total (8.7 avg/day)
# Rate: 795.7 queries/hour
# Elapsed: 0.66h | Est. remaining: 0.02h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-08-30
# (To predict VIX change on 2025-08-31)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 9/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 17/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 20/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 22/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 22/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 26/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 26/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 28/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 30/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 30/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 31/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 31/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 31 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 31 articles to data/vix_training/2025-08-30.csv
#
# ======================================================================
# Fetching articles for 2025-08-31
# (To predict VIX change on 2025-09-01)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 1/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 1/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 1/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 8/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 18/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 18/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 21/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 29/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 29/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +5 | Total: 34/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 34/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 37/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 18 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-08-31.csv
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 62
# Total articles: 2318
# Total queries: 539
# Average: 37.4 articles/day, 8.7 queries/day
# Runtime: 0.68 hours
# Query rate: 788.8 queries/hour
#
# 📁 Output: 62 CSV files in data/vix_training/
# ======================================================================

# %%
# Sept
START_DATE = datetime(2025, 9, 1)
END_DATE = datetime(2025, 9, 30)
ARTICLES_PER_DAY = 40

print("\n🚀 Starting KBE dataset collection...")
print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
print(f"⚡ Fast mode: 1-2 second delays\n")

# Run collection
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# 🚀 Starting KBE dataset collection...
# 📅 Date range: 2025-09-01 to 2025-09-30
# 🎯 Target: 40 articles per day
# ⚡ Fast mode: 1-2 second delays
#
#
# ======================================================================
# KBE PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-09-01 to 2025-09-30
# Total days: 30
# Target: 40 articles per day
# Query pool: 21 queries (Tier 1-3)
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-09-01
# (To predict VIX change on 2025-09-02)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 23/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 31/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-01.csv
#
# ======================================================================
# Fetching articles for 2025-09-02
# (To predict VIX change on 2025-09-03)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 17/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 27/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 39/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-02.csv
#
# ======================================================================
# Fetching articles for 2025-09-03
# (To predict VIX change on 2025-09-04)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +5 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-03.csv
#
# ======================================================================
# Fetching articles for 2025-09-04
# (To predict VIX change on 2025-09-05)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 17/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 30/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 37/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-04.csv
#
# ======================================================================
# Fetching articles for 2025-09-05
# (To predict VIX change on 2025-09-06)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 3/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 3/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 11/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 19/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 27/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 28/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +9 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 37/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 39/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 39/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 39/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 20 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-05.csv
#
# ======================================================================
# Fetching articles for 2025-09-06
# (To predict VIX change on 2025-09-07)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 9/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 13/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 13/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 13/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 15/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 16/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 19/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 19/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 22/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 23/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 23/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 23/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 23/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 23 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 23 articles to data/vix_training/2025-09-06.csv
#
# ======================================================================
# Fetching articles for 2025-09-07
# (To predict VIX change on 2025-09-08)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 32/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 37/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 37/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-07.csv
#
# ======================================================================
# Fetching articles for 2025-09-08
# (To predict VIX change on 2025-09-09)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-08.csv
#
# ======================================================================
# Fetching articles for 2025-09-09
# (To predict VIX change on 2025-09-10)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 9/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 19/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 19/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 20/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 20/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 30/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 39/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-09.csv
#
# ======================================================================
# Fetching articles for 2025-09-10
# (To predict VIX change on 2025-09-11)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 17/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 18/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 18/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 28/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-10.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 10/30 | Remaining: 20
# Articles: 383 total (38.3 avg/day)
# Queries: 82 total (8.2 avg/day)
# Rate: 845.5 queries/hour
# Elapsed: 0.10h | Est. remaining: 0.19h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-09-11
# (To predict VIX change on 2025-09-12)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +3 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 34/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-11.csv
#
# ======================================================================
# Fetching articles for 2025-09-12
# (To predict VIX change on 2025-09-13)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 22/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 22/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 24/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 29/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 30/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +7 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 37/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-12.csv
#
# ======================================================================
# Fetching articles for 2025-09-13
# (To predict VIX change on 2025-09-14)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 0/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 1/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 1/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 11/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 17/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 18/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 19/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 19/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +7 | Total: 26/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 26/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 27/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 27/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 27/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 28/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 28/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 28 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 28 articles to data/vix_training/2025-09-13.csv
#
# ======================================================================
# Fetching articles for 2025-09-14
# (To predict VIX change on 2025-09-15)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 24/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +5 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-14.csv
#
# ======================================================================
# Fetching articles for 2025-09-15
# (To predict VIX change on 2025-09-16)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +10 | Total: 36/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-15.csv
#
# ======================================================================
# Fetching articles for 2025-09-16
# (To predict VIX change on 2025-09-17)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-16.csv
#
# ======================================================================
# Fetching articles for 2025-09-17
# (To predict VIX change on 2025-09-18)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-17.csv
#
# ======================================================================
# Fetching articles for 2025-09-18
# (To predict VIX change on 2025-09-19)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 24/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +10 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 39/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-18.csv
#
# ======================================================================
# Fetching articles for 2025-09-19
# (To predict VIX change on 2025-09-20)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 1/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 1/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 1/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 11/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +7 | Total: 28/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 32/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 32/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 35/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 35/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 37/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 37/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +1 | Total: 38/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 39/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 39/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 39 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 39 articles to data/vix_training/2025-09-19.csv
#
# ======================================================================
# Fetching articles for 2025-09-20
# (To predict VIX change on 2025-09-21)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 3/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 3/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 12/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 14/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 14/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 15/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +0 | Total: 15/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 16/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 18/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 18/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 18/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 18/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 18/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +3 | Total: 21/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +1 | Total: 22/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 22 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 22 articles to data/vix_training/2025-09-20.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 20/30 | Remaining: 10
# Articles: 752 total (37.6 avg/day)
# Queries: 165 total (8.2 avg/day)
# Rate: 810.6 queries/hour
# Elapsed: 0.20h | Est. remaining: 0.10h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-09-21
# (To predict VIX change on 2025-09-22)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 33/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-21.csv
#
# ======================================================================
# Fetching articles for 2025-09-22
# (To predict VIX change on 2025-09-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 30/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 33/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-22.csv
#
# ======================================================================
# Fetching articles for 2025-09-23
# (To predict VIX change on 2025-09-24)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 33/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-23.csv
#
# ======================================================================
# Fetching articles for 2025-09-24
# (To predict VIX change on 2025-09-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 15/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 34/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-24.csv
#
# ======================================================================
# Fetching articles for 2025-09-25
# (To predict VIX change on 2025-09-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 28/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 28/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 36/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-25.csv
#
# ======================================================================
# Fetching articles for 2025-09-26
# (To predict VIX change on 2025-09-27)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 12/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 16/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 18/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 29/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 29/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 33/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 33/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 35/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +4 | Total: 39/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 39/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 20 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-26.csv
#
# ======================================================================
# Fetching articles for 2025-09-27
# (To predict VIX change on 2025-09-28)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +8 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 14/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 14/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 17/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 20/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 20/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 22/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 22/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 23/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 25/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 25/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 25/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 25/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 25 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 25 articles to data/vix_training/2025-09-27.csv
#
# ======================================================================
# Fetching articles for 2025-09-28
# (To predict VIX change on 2025-09-29)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 24/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 25/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 26/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 32/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 32/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-28.csv
#
# ======================================================================
# Fetching articles for 2025-09-29
# (To predict VIX change on 2025-09-30)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 27/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 27/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 36/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-29.csv
#
# ======================================================================
# Fetching articles for 2025-09-30
# (To predict VIX change on 2025-10-01)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-09-30.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 30/30 | Remaining: 0
# Articles: 1137 total (37.9 avg/day)
# Queries: 256 total (8.5 avg/day)
# Rate: 825.7 queries/hour
# Elapsed: 0.31h | Est. remaining: 0.00h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 30
# Total articles: 1137
# Total queries: 256
# Average: 37.9 articles/day, 8.5 queries/day
# Runtime: 0.31 hours
# Query rate: 823.2 queries/hour
#
# 📁 Output: 30 CSV files in data/vix_training/
# ======================================================================

# %%
# Oct - Nov
START_DATE = datetime(2025, 10, 1)
END_DATE = datetime(2025, 11, 30)
ARTICLES_PER_DAY = 40

print("\n🚀 Starting KBE dataset collection...")
print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
print(f"⚡ Fast mode: 1-2 second delays\n")

# Run collection
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# 🚀 Starting KBE dataset collection...
# 📅 Date range: 2025-10-01 to 2025-11-30
# 🎯 Target: 40 articles per day
# ⚡ Fast mode: 1-2 second delays
#
#
# ======================================================================
# KBE PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-10-01 to 2025-11-30
# Total days: 61
# Target: 40 articles per day
# Query pool: 21 queries (Tier 1-3)
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-10-01
# (To predict VIX change on 2025-10-02)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 15/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 25/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22Federal+Reserve%22+AND+emergency+AND+%28meeting+OR+action%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x12fa8f230>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22FOMC%22+AND+%28surprise+OR+unexpected%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3093ed220>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22Jerome+Powell%22+AND+%28emergency+OR+urgent%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3092cd580>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22commercial+real+estate%22+AND+%28default+OR+distress+OR+crisis%29+AND+bank+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3093ed220>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22CRE+loans%22+AND+%28losses+OR+writedown%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x12fa8ca70>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22credit+rating%22+AND+downgrade+AND+bank+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x309403c20>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22bank+earnings%22+AND+%22United+States%22+AND+%28warning+OR+miss%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3093cb080>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22net+interest+margin%22+AND+%28compress+OR+decline%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x30934c3b0>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22bank+reserves%22+AND+%28decline+OR+drain%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3092ce9c0>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22loan+losses%22+AND+%28rising+OR+surge%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3093ca420>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22stress+test%22+AND+%28fail+OR+concern%29+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x12f987860>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   ✗ Error: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /rss/search?q=%22Treasury+yields%22+AND+spike+AND+banks+after%3A2025-10-01+before%3A2025-10-02&ceid=US:en&hl=en&gl=US (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x3093efaa0>: Failed to resolve 'news.google.com' ([Errno 8] nodename nor servname provided, or not known)"))
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 25 articles from 9 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 25 articles to data/vix_training/2025-10-01.csv
#
# ======================================================================
# Fetching articles for 2025-10-02
# (To predict VIX change on 2025-10-03)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 20/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 33/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 33/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +6 | Total: 39/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 39/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 39/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 18 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-02.csv
#
# ======================================================================
# Fetching articles for 2025-10-03
# (To predict VIX change on 2025-10-04)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 1/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 1/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 1/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 11/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 14/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 15/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 18/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 24/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 24/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +6 | Total: 30/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 30/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +4 | Total: 34/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +3 | Total: 37/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 37/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 38/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 38/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 38 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 38 articles to data/vix_training/2025-10-03.csv
#
# ======================================================================
# Fetching articles for 2025-10-04
# (To predict VIX change on 2025-10-05)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 12/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 18/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 24/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 24/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 27/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 27/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +6 | Total: 33/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 34/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 34/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 34/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 34/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 34 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 34 articles to data/vix_training/2025-10-04.csv
#
# ======================================================================
# Fetching articles for 2025-10-05
# (To predict VIX change on 2025-10-06)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 35/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 36/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 37/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-05.csv
#
# ======================================================================
# Fetching articles for 2025-10-06
# (To predict VIX change on 2025-10-07)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +6 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 20/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 21/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 22/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 22/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 32/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-06.csv
#
# ======================================================================
# Fetching articles for 2025-10-07
# (To predict VIX change on 2025-10-08)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +5 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 18/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 19/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 19/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 19/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 29/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 38/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-07.csv
#
# ======================================================================
# Fetching articles for 2025-10-08
# (To predict VIX change on 2025-10-09)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 12/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 19/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 19/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 19/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 19/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 29/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 35/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +3 | Total: 38/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-08.csv
#
# ======================================================================
# Fetching articles for 2025-10-09
# (To predict VIX change on 2025-10-10)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 33/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-09.csv
#
# ======================================================================
# Fetching articles for 2025-10-10
# (To predict VIX change on 2025-10-11)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 17/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 18/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 28/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +5 | Total: 33/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 33/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +4 | Total: 37/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 38/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 38/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 38/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 38/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 38 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 38 articles to data/vix_training/2025-10-10.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 10/61 | Remaining: 51
# Articles: 375 total (37.5 avg/day)
# Queries: 84 total (8.4 avg/day)
# Rate: 108.9 queries/hour
# Elapsed: 0.77h | Est. remaining: 3.93h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-10-11
# (To predict VIX change on 2025-10-12)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 2/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 2/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 11/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 13/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 14/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 16/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 19/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 19/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +5 | Total: 24/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 24/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 27/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 27/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 27/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 28/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 28/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 28 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 28 articles to data/vix_training/2025-10-11.csv
#
# ======================================================================
# Fetching articles for 2025-10-12
# (To predict VIX change on 2025-10-13)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 3/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 3/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 3/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 30/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 31/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +6 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +1 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-12.csv
#
# ======================================================================
# Fetching articles for 2025-10-13
# (To predict VIX change on 2025-10-14)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 33/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-13.csv
#
# ======================================================================
# Fetching articles for 2025-10-14
# (To predict VIX change on 2025-10-15)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 14/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 14/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 14/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 24/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 24/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 25/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 25/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 35/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-14.csv
#
# ======================================================================
# Fetching articles for 2025-10-15
# (To predict VIX change on 2025-10-16)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +9 | Total: 18/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +3 | Total: 21/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +4 | Total: 25/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 32/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 32/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +3 | Total: 35/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 35/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 9 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-15.csv
#
# ======================================================================
# Fetching articles for 2025-10-16
# (To predict VIX change on 2025-10-17)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +9 | Total: 19/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +4 | Total: 23/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +9 | Total: 32/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 37/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 37/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +2 | Total: 39/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 39/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 9 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-16.csv
#
# ======================================================================
# Fetching articles for 2025-10-17
# (To predict VIX change on 2025-10-18)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +10 | Total: 20/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 21/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +8 | Total: 29/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 35/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 36/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 37/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 38/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 9 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-17.csv
#
# ======================================================================
# Fetching articles for 2025-10-18
# (To predict VIX change on 2025-10-19)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +7 | Total: 15/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 15/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 16/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 21/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 22/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 22/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 23/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 32/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 37/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 38/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-18.csv
#
# ======================================================================
# Fetching articles for 2025-10-19
# (To predict VIX change on 2025-10-20)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +9 | Total: 19/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 19/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +6 | Total: 25/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 32/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 32/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 33/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 33/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 9 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-19.csv
#
# ======================================================================
# Fetching articles for 2025-10-20
# (To predict VIX change on 2025-10-21)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +9 | Total: 19/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 19/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +5 | Total: 24/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 32/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 32/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 33/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 33/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 9 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-20.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 20/61 | Remaining: 41
# Articles: 763 total (38.1 avg/day)
# Queries: 164 total (8.2 avg/day)
# Rate: 192.8 queries/hour
# Elapsed: 0.85h | Est. remaining: 1.74h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-10-21
# (To predict VIX change on 2025-10-22)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +9 | Total: 18/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 18/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 20/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 28/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 28/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 28/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 28/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 37/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-21.csv
#
# ======================================================================
# Fetching articles for 2025-10-22
# (To predict VIX change on 2025-10-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +8 | Total: 17/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 17/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 18/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 26/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 26/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 26/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 26/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 35/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-22.csv
#
# ======================================================================
# Fetching articles for 2025-10-23
# (To predict VIX change on 2025-10-24)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +9 | Total: 17/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +2 | Total: 19/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 19/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 25/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 25/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 25/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 25/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 35/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-10-23.csv
#
# ======================================================================
# Fetching articles for 2025-10-24
# (To predict VIX change on 2025-10-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 12/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 13/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
# ...
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 25/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 27/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 27/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 38/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-11-23.csv
#
# ======================================================================
# Fetching articles for 2025-11-24
# (To predict VIX change on 2025-11-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +6 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-11-24.csv
#
# ======================================================================
# Fetching articles for 2025-11-25
# (To predict VIX change on 2025-11-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 8/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 23/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 27/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 29/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 37/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 37/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-11-25.csv
#
# ======================================================================
# Fetching articles for 2025-11-26
# (To predict VIX change on 2025-11-27)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 17/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 19/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 20/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 30/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 30/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +8 | Total: 38/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-11-26.csv
#
# ======================================================================
# Fetching articles for 2025-11-27
# (To predict VIX change on 2025-11-28)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 21/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 22/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 28/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +9 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 37/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-11-27.csv
#
# ======================================================================
# Fetching articles for 2025-11-28
# (To predict VIX change on 2025-11-29)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 2/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 3/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 13/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 15/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 16/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 17/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 24/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 24/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 26/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 26/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 29/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 31/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 31/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +2 | Total: 33/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 33/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 33 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 33 articles to data/vix_training/2025-11-28.csv
#
# ======================================================================
# Fetching articles for 2025-11-29
# (To predict VIX change on 2025-11-30)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 0/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 0/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 0/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +0 | Total: 0/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 0/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 1/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 2/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 12/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 16/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 17/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 18/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 26/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 27/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 29/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 29/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 30/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +5 | Total: 35/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +1 | Total: 36/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 36/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 36/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 36 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 36 articles to data/vix_training/2025-11-29.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 60/61 | Remaining: 1
# Articles: 2336 total (38.9 avg/day)
# Queries: 532 total (8.9 avg/day)
# Rate: 436.3 queries/hour
# Elapsed: 1.22h | Est. remaining: 0.02h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-11-30
# (To predict VIX change on 2025-12-01)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-11-30.csv
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 61
# Total articles: 2376
# Total queries: 541
# Average: 39.0 articles/day, 8.9 queries/day
# Runtime: 1.23 hours
# Query rate: 440.4 queries/hour
#
# 📁 Output: 61 CSV files in data/vix_training/
# ======================================================================

# %%
# Dec
START_DATE = datetime(2025, 12, 1)
END_DATE = datetime(2025, 12, 31)
ARTICLES_PER_DAY = 40

print("\n🚀 Starting KBE dataset collection...")
print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
print(f"⚡ Fast mode: 1-2 second delays\n")

# Run collection
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# 🚀 Starting KBE dataset collection...
# 📅 Date range: 2025-12-01 to 2025-12-31
# 🎯 Target: 40 articles per day
# ⚡ Fast mode: 1-2 second delays
#
#
# ======================================================================
# KBE PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2025-12-01 to 2025-12-31
# Total days: 31
# Target: 40 articles per day
# Query pool: 21 queries (Tier 1-3)
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2025-12-01
# (To predict VIX change on 2025-12-02)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 9/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 18/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 18/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 19/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 19/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 29/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 38/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-01.csv
#
# ======================================================================
# Fetching articles for 2025-12-02
# (To predict VIX change on 2025-12-03)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 22/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 22/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 23/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 23/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 33/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-02.csv
#
# ======================================================================
# Fetching articles for 2025-12-03
# (To predict VIX change on 2025-12-04)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 16/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 17/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 17/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 17/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-03.csv
#
# ======================================================================
# Fetching articles for 2025-12-04
# (To predict VIX change on 2025-12-05)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +9 | Total: 37/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-04.csv
#
# ======================================================================
# Fetching articles for 2025-12-05
# (To predict VIX change on 2025-12-06)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 7/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 7/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 7/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +9 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 22/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 26/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 27/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 34/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 35/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 38/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +1 | Total: 39/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 18 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-05.csv
#
# ======================================================================
# Fetching articles for 2025-12-06
# (To predict VIX change on 2025-12-07)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 4/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 4/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 4/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 4/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 14/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +6 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 23/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 28/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 28/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 30/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 30/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 32/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +3 | Total: 35/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 35/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 36/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 36/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 36 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 36 articles to data/vix_training/2025-12-06.csv
#
# ======================================================================
# Fetching articles for 2025-12-07
# (To predict VIX change on 2025-12-08)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +9 | Total: 38/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-07.csv
#
# ======================================================================
# Fetching articles for 2025-12-08
# (To predict VIX change on 2025-12-09)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 19/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 20/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 20/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 20/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 30/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-08.csv
#
# ======================================================================
# Fetching articles for 2025-12-09
# (To predict VIX change on 2025-12-10)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 16/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-09.csv
#
# ======================================================================
# Fetching articles for 2025-12-10
# (To predict VIX change on 2025-12-11)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-10.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 10/31 | Remaining: 21
# Articles: 396 total (39.6 avg/day)
# Queries: 81 total (8.1 avg/day)
# Rate: 979.2 queries/hour
# Elapsed: 0.08h | Est. remaining: 0.17h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-12-11
# (To predict VIX change on 2025-12-12)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 17/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 17/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 27/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-11.csv
#
# ======================================================================
# Fetching articles for 2025-12-12
# (To predict VIX change on 2025-12-13)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 25/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +6 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +6 | Total: 37/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-12.csv
#
# ======================================================================
# Fetching articles for 2025-12-13
# (To predict VIX change on 2025-12-14)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 15/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 17/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 19/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 26/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 26/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 29/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 29/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 32/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +3 | Total: 35/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +1 | Total: 36/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 37/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 37/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 37 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 37 articles to data/vix_training/2025-12-13.csv
#
# ======================================================================
# Fetching articles for 2025-12-14
# (To predict VIX change on 2025-12-15)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 28/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 34/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-14.csv
#
# ======================================================================
# Fetching articles for 2025-12-15
# (To predict VIX change on 2025-12-16)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 34/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 38/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-15.csv
#
# ======================================================================
# Fetching articles for 2025-12-16
# (To predict VIX change on 2025-12-17)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 9/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +5 | Total: 37/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 38/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-16.csv
#
# ======================================================================
# Fetching articles for 2025-12-17
# (To predict VIX change on 2025-12-18)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 11/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +2 | Total: 19/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 19/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 19/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 29/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 36/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 11 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-17.csv
#
# ======================================================================
# Fetching articles for 2025-12-18
# (To predict VIX change on 2025-12-19)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 7/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +5 | Total: 18/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 18/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 18/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 28/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 33/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 38/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-18.csv
#
# ======================================================================
# Fetching articles for 2025-12-19
# (To predict VIX change on 2025-12-20)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +4 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 22/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 23/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 25/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +8 | Total: 33/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 34/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +4 | Total: 38/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +0 | Total: 38/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 18 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-19.csv
#
# ======================================================================
# Fetching articles for 2025-12-20
# (To predict VIX change on 2025-12-21)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +1 | Total: 6/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 6/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 6/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 6/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 16/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 16/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 16/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 17/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +0 | Total: 17/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 18/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 20/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 20/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 23/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +0 | Total: 23/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 23/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 24/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 24/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 24 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 24 articles to data/vix_training/2025-12-20.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 20/31 | Remaining: 11
# Articles: 777 total (38.9 avg/day)
# Queries: 174 total (8.7 avg/day)
# Rate: 982.8 queries/hour
# Elapsed: 0.18h | Est. remaining: 0.10h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-12-21
# (To predict VIX change on 2025-12-22)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +2 | Total: 10/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 10/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 10/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 10/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 20/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 21/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 22/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 26/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 26/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 28/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 28/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +4 | Total: 32/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +3 | Total: 35/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 35/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +4 | Total: 39/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +1 | Total: 40/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-21.csv
#
# ======================================================================
# Fetching articles for 2025-12-22
# (To predict VIX change on 2025-12-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 11/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 19/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 19/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 19/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 19/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 29/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 32/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +6 | Total: 38/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 38/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-22.csv
#
# ======================================================================
# Fetching articles for 2025-12-23
# (To predict VIX change on 2025-12-24)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 10/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 18/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 18/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 18/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 28/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 30/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 39/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 39/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-23.csv
#
# ======================================================================
# Fetching articles for 2025-12-24
# (To predict VIX change on 2025-12-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 7/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 8/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +0 | Total: 18/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 19/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 21/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +5 | Total: 26/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 27/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 29/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 29/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +9 | Total: 38/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 39/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 39/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 20 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-24.csv
#
# ======================================================================
# Fetching articles for 2025-12-25
# (To predict VIX change on 2025-12-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +6 | Total: 11/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +1 | Total: 12/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 12/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 13/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 15/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 15/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 18/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 18/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +5 | Total: 23/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +2 | Total: 25/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 25/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +4 | Total: 29/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 29/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 29 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 29 articles to data/vix_training/2025-12-25.csv
#
# ======================================================================
# Fetching articles for 2025-12-26
# (To predict VIX change on 2025-12-27)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +4 | Total: 5/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 5/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 5/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 5/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 15/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 18/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 18/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 19/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 23/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 23/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 24/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 24/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +6 | Total: 30/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 31/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +0 | Total: 31/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +2 | Total: 33/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 33/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 33 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 33 articles to data/vix_training/2025-12-26.csv
#
# ======================================================================
# Fetching articles for 2025-12-27
# (To predict VIX change on 2025-12-28)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 8/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 8/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 8/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 8/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 18/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 21/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 21/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +0 | Total: 21/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 25/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 25/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 27/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 27/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 29/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 30/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +1 | Total: 31/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 31/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 31/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 31 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 31 articles to data/vix_training/2025-12-27.csv
#
# ======================================================================
# Fetching articles for 2025-12-28
# (To predict VIX change on 2025-12-29)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +0 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +4 | Total: 27/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 28/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 32/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 39/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 39/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-28.csv
#
# ======================================================================
# Fetching articles for 2025-12-29
# (To predict VIX change on 2025-12-30)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +1 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 25/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 34/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 36/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-29.csv
#
# ======================================================================
# Fetching articles for 2025-12-30
# (To predict VIX change on 2025-12-31)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 39/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-30.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 30/31 | Remaining: 1
# Articles: 1150 total (38.3 avg/day)
# Queries: 276 total (9.2 avg/day)
# Rate: 951.5 queries/hour
# Elapsed: 0.29h | Est. remaining: 0.01h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2025-12-31
# (To predict VIX change on 2026-01-01)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 30/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 33/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2025-12-31.csv
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 31
# Total articles: 1190
# Total queries: 284
# Average: 38.4 articles/day, 9.2 queries/day
# Runtime: 0.30 hours
# Query rate: 949.3 queries/hour
#
# 📁 Output: 31 CSV files in data/vix_training/
# ======================================================================

# %%
# Jan 2026
START_DATE = datetime(2026, 1, 1)
END_DATE = datetime(2026, 1, 31)
ARTICLES_PER_DAY = 40

print("\n🚀 Starting KBE dataset collection...")
print(f"📅 Date range: {START_DATE.strftime('%Y-%m-%d')} to {END_DATE.strftime('%Y-%m-%d')}")
print(f"🎯 Target: {ARTICLES_PER_DAY} articles per day")
print(f"⚡ Fast mode: 1-2 second delays\n")

# Run collection
run_date_range(START_DATE, END_DATE, max_articles_per_day=ARTICLES_PER_DAY)
# Out:
# 🚀 Starting KBE dataset collection...
# 📅 Date range: 2026-01-01 to 2026-01-31
# 🎯 Target: 40 articles per day
# ⚡ Fast mode: 1-2 second delays
#
#
# ======================================================================
# KBE PREDICTION DATASET COLLECTION
# ======================================================================
# Date range: 2026-01-01 to 2026-01-31
# Total days: 31
# Target: 40 articles per day
# Query pool: 21 queries (Tier 1-3)
# ======================================================================
#
#
# ======================================================================
# Fetching articles for 2026-01-01
# (To predict VIX change on 2026-01-02)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 33/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 33/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 38/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-01.csv
#
# ======================================================================
# Fetching articles for 2026-01-02
# (To predict VIX change on 2026-01-03)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +9 | Total: 38/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-02.csv
#
# ======================================================================
# Fetching articles for 2026-01-03
# (To predict VIX change on 2026-01-04)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 1/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 1/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 1/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 22/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 22/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 30/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +10 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-03.csv
#
# ======================================================================
# Fetching articles for 2026-01-04
# (To predict VIX change on 2026-01-05)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 17/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 17/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 17/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 27/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 29/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 31/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-04.csv
#
# ======================================================================
# Fetching articles for 2026-01-05
# (To predict VIX change on 2026-01-06)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 16/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 34/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 34/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-05.csv
#
# ======================================================================
# Fetching articles for 2026-01-06
# (To predict VIX change on 2026-01-07)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +7 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 8/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 8/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 17/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 17/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 17/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 27/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 35/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 35/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 38/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-06.csv
#
# ======================================================================
# Fetching articles for 2026-01-07
# (To predict VIX change on 2026-01-08)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +3 | Total: 3/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 9/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 18/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 18/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 18/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 18/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 28/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 37/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-07.csv
#
# ======================================================================
# Fetching articles for 2026-01-08
# (To predict VIX change on 2026-01-09)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 30/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 39/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-08.csv
#
# ======================================================================
# Fetching articles for 2026-01-09
# (To predict VIX change on 2026-01-10)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 26/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 26/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 31/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 34/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 34/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +3 | Total: 37/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 37/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-09.csv
#
# ======================================================================
# Fetching articles for 2026-01-10
# (To predict VIX change on 2026-01-11)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 4/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +5 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 27/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 27/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 32/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +0 | Total: 32/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +0 | Total: 32/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +0 | Total: 32/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 32/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +5 | Total: 37/40
# [18/21] P=6 | "bank reserves" AND (decline OR drain)...
#   → +1 | Total: 38/40
# [19/21] P=6 | "loan losses" AND (rising OR surge)...
#   → +1 | Total: 39/40
# [20/21] P=6 | "stress test" AND (fail OR concern)...
#   → +0 | Total: 39/40
# [21/21] P=6 | "Treasury yields" AND spike AND banks...
#   → +0 | Total: 39/40
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 39 articles from 21 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 39 articles to data/vix_training/2026-01-10.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 10/31 | Remaining: 21
# Articles: 399 total (39.9 avg/day)
# Queries: 76 total (7.6 avg/day)
# Rate: 816.0 queries/hour
# Elapsed: 0.09h | Est. remaining: 0.20h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2026-01-11
# (To predict VIX change on 2026-01-12)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 5/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 5/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 37/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 13 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-11.csv
#
# ======================================================================
# Fetching articles for 2026-01-12
# (To predict VIX change on 2026-01-13)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +3 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 34/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +2 | Total: 36/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-12.csv
#
# ======================================================================
# Fetching articles for 2026-01-13
# (To predict VIX change on 2026-01-14)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 4/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 4/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 5/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 13/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 13/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 13/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 13/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 23/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 33/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +3 | Total: 36/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-13.csv
#
# ======================================================================
# Fetching articles for 2026-01-14
# (To predict VIX change on 2026-01-15)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 10/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 16/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 34/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 35/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-14.csv
#
# ======================================================================
# Fetching articles for 2026-01-15
# (To predict VIX change on 2026-01-16)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +9 | Total: 9/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 21/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 21/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 21/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 21/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 31/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-15.csv
#
# ======================================================================
# Fetching articles for 2026-01-16
# (To predict VIX change on 2026-01-17)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 14/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 14/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 14/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 14/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 24/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 32/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-16.csv
#
# ======================================================================
# Fetching articles for 2026-01-17
# (To predict VIX change on 2026-01-18)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +4 | Total: 4/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 9/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 9/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 9/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +3 | Total: 12/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 12/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 12/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 12/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 22/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +5 | Total: 36/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +0 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +1 | Total: 37/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +1 | Total: 38/40
# [16/21] P=6 | "bank earnings" AND "United States" AND (warning OR miss)...
#   → +0 | Total: 38/40
# [17/21] P=6 | "net interest margin" AND (compress OR decline)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 17 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-17.csv
#
# ======================================================================
# Fetching articles for 2026-01-18
# (To predict VIX change on 2026-01-19)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 8/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 9/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 10/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 17/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 17/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 17/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 27/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 37/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 37/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-18.csv
#
# ======================================================================
# Fetching articles for 2026-01-19
# (To predict VIX change on 2026-01-20)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 17/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 17/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 17/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 17/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 27/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 37/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 37/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-19.csv
#
# ======================================================================
# Fetching articles for 2026-01-20
# (To predict VIX change on 2026-01-21)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +10 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 11/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 20/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 20/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 20/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 20/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 30/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-20.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 20/31 | Remaining: 11
# Articles: 799 total (40.0 avg/day)
# Queries: 148 total (7.4 avg/day)
# Rate: 845.2 queries/hour
# Elapsed: 0.18h | Est. remaining: 0.10h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2026-01-21
# (To predict VIX change on 2026-01-22)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +10 | Total: 16/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 16/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 16/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 26/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 27/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 27/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 27/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 37/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-21.csv
#
# ======================================================================
# Fetching articles for 2026-01-22
# (To predict VIX change on 2026-01-23)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +6 | Total: 6/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +10 | Total: 16/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 16/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 16/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +10 | Total: 26/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 26/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 27/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 27/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 37/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-22.csv
#
# ======================================================================
# Fetching articles for 2026-01-23
# (To predict VIX change on 2026-01-24)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +8 | Total: 10/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 11/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 11/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 18/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 18/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +1 | Total: 19/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 19/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 29/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +8 | Total: 37/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 37/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +3 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-23.csv
#
# ======================================================================
# Fetching articles for 2026-01-24
# (To predict VIX change on 2026-01-25)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 7/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 7/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 15/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 15/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 15/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 25/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +0 | Total: 31/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +4 | Total: 35/40
# [13/21] P=8 | "commercial real estate" AND (default OR distress OR crisis) AND ...
#   → +1 | Total: 36/40
# [14/21] P=8 | "CRE loans" AND (losses OR writedown)...
#   → +2 | Total: 38/40
# [15/21] P=8 | "credit rating" AND downgrade AND bank...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 15 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-24.csv
#
# ======================================================================
# Fetching articles for 2026-01-25
# (To predict VIX change on 2026-01-26)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +1 | Total: 1/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 6/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 6/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 6/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 15/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 16/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 16/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 16/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 26/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +5 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-25.csv
#
# ======================================================================
# Fetching articles for 2026-01-26
# (To predict VIX change on 2026-01-27)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +5 | Total: 5/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 11/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +1 | Total: 12/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +1 | Total: 13/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +9 | Total: 22/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +1 | Total: 23/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 23/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 23/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 33/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +7 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-26.csv
#
# ======================================================================
# Fetching articles for 2026-01-27
# (To predict VIX change on 2026-01-28)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +2 | Total: 2/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +1 | Total: 3/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 3/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 3/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +8 | Total: 11/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 11/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 11/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 11/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 21/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 31/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +8 | Total: 39/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +1 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-27.csv
#
# ======================================================================
# Fetching articles for 2026-01-28
# (To predict VIX change on 2026-01-29)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +10 | Total: 10/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +5 | Total: 15/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 15/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 15/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +6 | Total: 21/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 21/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 21/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 21/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 31/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +9 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-28.csv
#
# ======================================================================
# Fetching articles for 2026-01-29
# (To predict VIX change on 2026-01-30)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +0 | Total: 0/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +2 | Total: 2/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 2/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 2/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 9/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 9/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 9/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 9/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 19/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +10 | Total: 29/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +3 | Total: 32/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +8 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-29.csv
#
# ======================================================================
# Fetching articles for 2026-01-30
# (To predict VIX change on 2026-01-31)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +7 | Total: 7/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +6 | Total: 13/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +4 | Total: 17/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +0 | Total: 17/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 24/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +0 | Total: 24/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 24/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 24/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 34/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +6 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 10 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-30.csv
#
# ══════════════════════════════════════════════════════════════════════
# 📊 PROGRESS UPDATE
# ══════════════════════════════════════════════════════════════════════
# Days: 30/31 | Remaining: 1
# Articles: 1199 total (40.0 avg/day)
# Queries: 218 total (7.3 avg/day)
# Rate: 863.9 queries/hour
# Elapsed: 0.25h | Est. remaining: 0.01h
# ══════════════════════════════════════════════════════════════════════
#
#
# ======================================================================
# Fetching articles for 2026-01-31
# (To predict VIX change on 2026-02-01)
# Target: 40 articles | Max queries: 21
# ======================================================================
# [1/21] P=10 | ("First Republic" OR "Silicon Valley Bank" OR "Signature Bank") A...
#   → +8 | Total: 8/40
# [2/21] P=10 | ("PacWest" OR "Western Alliance" OR "Zions" OR "NYCB") AND (stres...
#   → +4 | Total: 12/40
# [3/21] P=10 | "New York Community Bancorp" AND (warning OR loss OR concern OR w...
#   → +0 | Total: 12/40
# [4/21] P=10 | "regional bank" AND "United States" AND (failure OR crisis OR str...
#   → +2 | Total: 14/40
# [5/21] P=10 | "regional bank" AND (deposit OR outflow OR run)...
#   → +7 | Total: 21/40
# [6/21] P=10 | "FDIC" AND (takeover OR receivership OR intervention)...
#   → +4 | Total: 25/40
# [7/21] P=10 | "Fed emergency" AND (facility OR liquidity)...
#   → +0 | Total: 25/40
# [8/21] P=10 | "discount window" AND surge...
#   → +0 | Total: 25/40
# [9/21] P=8 | ("JPMorgan" OR "Bank of America" OR "Wells Fargo" OR "Citigroup")...
#   → +10 | Total: 35/40
# [10/21] P=8 | "Federal Reserve" AND emergency AND (meeting OR action)...
#   → +2 | Total: 37/40
# [11/21] P=8 | "FOMC" AND (surprise OR unexpected)...
#   → +1 | Total: 38/40
# [12/21] P=8 | "Jerome Powell" AND (emergency OR urgent)...
#   → +2 | Total: 40/40
#
# ✓ Reached target of 40 articles. Stopping.
#
# ──────────────────────────────────────────────────────────────────────
# SUMMARY: 40 articles from 12 queries
# ──────────────────────────────────────────────────────────────────────
#   ✓ Saved 40 articles to data/vix_training/2026-01-31.csv
#
# ======================================================================
# 🎉 COLLECTION COMPLETE
# ======================================================================
# Days processed: 31
# Total articles: 1239
# Total queries: 227
# Average: 40.0 articles/day, 7.3 queries/day
# Runtime: 0.26 hours
# Query rate: 869.8 queries/hour
#
# 📁 Output: 31 CSV files in data/vix_training/
# ======================================================================
